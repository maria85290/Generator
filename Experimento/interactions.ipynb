# %%
import pandas as pd

data = pd.read_csv('interactions.csv')

# %%
data
# Out:
#     post_id             approach  likes  replies  retweets  shares  blocks  \
# 0         1  allegation_sentence     16        1         2       5       0
# 1         2                   t5     14        0         1       3       0
# 2         3               snopes      0        0         0       0       0
# 3         4  allegation_sentence     10        2         4       1       0
# 4         5                   t5     11        0         3       1       0
# 5         6               snopes      0        0         0       0       2
# 6         7  allegation_sentence     12        0         2       1       0
# 7         8                   t5      8        0         0       0       0
# 8         9               snopes      0        0         0       0       5
# 9        10  allegation_sentence     13        0         2       1       0
# 10       11                   t5     10        0         2       0       0
# 11       12               snopes      0        0         0       0       2
# 12       13  allegation_sentence     12        0         5       0       0
# 13       14                   t5     11        1         4       0       0
# 14       15               snopes      1        0         0       0       5
# 15       16  allegation_sentence     17        0        10       3       0
# 16       17                   t5     15        0         8       1       0
# 17       18               snopes      2        0         2       0       0
# 18       19  allegation_sentence      8        0         2       0       0
# 19       20                   t5      5        0         3       0       3
# 20       21               snopes      7        0         3       0       0
# 21       22  allegation_sentence      2        0         0       0       2
# 22       23                   t5      0        0         0       0       3
# 23       24               snopes      0        0         0       0       0
# 24       25  allegation_sentence     10        0         4       1       0
# 25       26                   t5     11        0         4       2       0
# 26       27               snopes      0        0         0       0       5
# 27       28  allegation_sentence     14        0         6       1       0
# 28       29                   t5     15        1         5       0       0
# 29       30               snopes      1        0         0       0       3
#
#     follows
# 0        14
# 1        10
# 2         0
# 3         3
# 4         0
# 5         0
# 6         3
# 7         0
# 8         0
# 9         1
# 10        1
# 11        0
# 12        0
# 13        2
# 14        0
# 15       10
# 16        9
# 17        1
# 18        0
# 19        0
# 20        1
# 21        0
# 22        0
# 23        0
# 24        4
# 25        3
# 26        0
# 27        8
# 28        9
# 29        0

# %% [markdown]
# ## Testes de normalidade

# %%
import scipy.stats as stats 
from scipy.stats import mannwhitneyu, ttest_ind

# %%
pip install seaborn

# %%
import seaborn as sns
sns.distplot(a=data["likes"], hist=True)
# Out:
# /var/folders/7v/nzkm4hw14qv5j4fghjbfccgr0000gn/T/ipykernel_5998/1245416603.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=data["likes"], hist=True)
# <AxesSubplot: xlabel='likes', ylabel='Density'>

# %%
from scipy import stats
shapiro_test = stats.shapiro(data['likes'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.8790819048881531, pvalue=0.0026857773773372173)

# %%
from scipy import stats
stats.kstest(data["likes"], "norm")
# Out:
# KstestResult(statistic=0.6772498680518209, pvalue=3.758697420531238e-14)
